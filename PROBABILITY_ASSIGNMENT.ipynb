# %% [markdown]
# # Question 1: A die is rolled. What is the probability of getting:
# # (a) An even number
# # (b) A number greater than 4
#
# ANSWER1
#
# 1. EVEN IS 2,4,6  TOTAL OUTCOME IS 6
#
#  3/6 = 0.5 PROBABILTY
#
# 2. 5 AND 6 ARE GREATER THAN 4
#
# 2/6 = 0.33333 OR  1/3

# %% [markdown]
# # Question 2: In a class of 50 students:
#
# # 20 like Mathematics (M)
#
# # 15 like Science (S)
#
# # 5 like both subjects
#
# # What is the probability that a student chosen at random likes Mathematics or Science
#
# 1. TOTAL STUDENT IS 50
#
# 2. TOTAL NO OF STUDENT WHO LIKE SCIENCE AND MATH ONLY  IS (20+15-5) = 30
#
# 3. PROBABILTY IS 30/50 = 0.6 OR 3/5

# %% [markdown]
# # Question 3: A bag has 3 red and 2 blue balls. If one ball is drawn randomly and is red, what is the probability
#
# # that the next ball is also red (without replacement)?
#
# ANSWER 3
#
# 1. TOTAL BALLS 4 BECAUSE ONE BALL IS DRAWN
#
# 2. RED IS 2 ONE BALL DRAWN
#
# 3. PROBABILITY IS  2/4 = 0.5

# %% [markdown]
# # Question 4: The population of a school is divided into 60% boys and 40% girls. If you want equal representation of both genders in the sample, which method should you use: Simple Random Sampling or Stratified Sampling?  Why?
#
# ANSWER
#
# 1. STRATIFIED SAMPLING METHOD POPULATION IS UNEQUAL
#
# 2. SO USING STRATIFIED SAMPLING ENSURES EQUAL REPRESENTATION  OF BOYS AND GIRLS
#
# 3. AND IT DOES NOT PICK  MORE BOY DUE TO HIGHER POPULATION
#
# 4. ALSO STRATIFIED DIVIDED INTO GROUP OR STRATA WHICH IS USEFUL IN THIS CASE

# %% [markdown]
# # Question 5: The average height of 1000 students = 160 cm. A sample of 100 students shows an average height = 158 cm.
# # Find the sampling error.
#
# ANSWER5
#
# 1. POPULATION MEAN IS 160CM
#
# 2. SAMPLE MEAN IS 158CM
#
# 3. ERROR IS 2CM (160-158)

# %% [markdown]
# # Question 6: The population mean salary is ₹50,000 with σ = ₹5,000. If we take a sample of 100 employees, what is the standard error of the mean (SEM)?
#
# ANSWER6
#
# 1. POPULATION STANDARD DEVIATION IS 5000
#
# 2.  SAMPLE DEVIATION IS 5000/10 = 500  (SD/SQUARE OF SAMPLE NUMBER )

# %% [markdown]
# # Question 7: In a group of 100 students:
#
# # 40 like Cricket (C)
#
# # 30 like Football (F)
#
# # 10 like both Cricket and Football
#
# # Find the probability that a student likes at least one sport
#
#
# ANSWER
#
# 1. TOTAL STUDENT 100
#
#
# 2.  PROBABILITY THAT A STUDENT LIKE A LEAST ONE SPORT IS = 40+30-10 = 60
#
# 60/100 =  0.6 OR 3/5

# %% [markdown]
# # Question 8: From a deck of 52 cards, two cards are drawn without replacement. What is the probability that both are Aces?
#
# ANSWER 8
#
#
# 1. TOTAL CARD 52  AND THERE ARE 4 SET ONE SET CONTAIN 13 CARD
#
#
# 2. THERE ARE 4 ACE IN 52 CARD
#
#
# 3. PROBABILITY OF ONE CARD IS 4/52 = 0.076
#
#
# 4. ONE CARD DRAWN 3 LEFT
#
#
# 5. 3/51=  0.058
#
#
# 6. AND MULTIPLY BOTH PROBABILITY ANSWER IS 1/221 =  0.00452

# %% [markdown]
# # Question 9: A factory produces bulbs with 2% defective rate. If 5 bulbs are chosen at random, what is the probability that all are non-defective?
#
# ANSWER 9
#
# 1. TOTAL NO OF BULB 5
#
# 2. PERCENTAGE OF DEFECIVE RATE IS 2%  THAT MEAN NON DEFETIVE RATE IS 1-2% =
# 0.98
#
# 3. 0.98^5 = 0.9039

# %% [markdown]
# # Question 10: Differentiate between discrete and continuous random variables with examples
#
# 1. DISCRET MEAN  A  VARIABLE THAT CAN COUNTABLE AND DISTINCT  YOU CAN LIST THEM INDIVIDUAL  . MEAN IT TAKE ONLY SPECIFIC VALUE ONLY
#
# EXAMPLE FLIP COIN 1,2,3
#
# 2. CONTINUOUS RANDOM MEAN IT CAN TAKE ANY VALUE FROM VARIABLE . MEAN IT CANNOT TAKE SPECIFIC VALUE
#
# EXAMPLE 16.25 KG
