# %% [markdown]
# # QUESTION1. Understanding Central Tendency . A bakery tracks the daily sales of muffins (in dozens) over a week: [10, 12, 11, 15, 14, 13, 12].
# Q1. What is the most representative value of their weekly sales, and why
#
# ANSWER1.(10,11,12,12,13,14,15)
# 1. MEAN OF THIS NUMBER IS =12.42 (10+11+12+12+13+14+15/7)
#
# 2. MODE IS 12 MOST THE MOST REPRENSTIVE VALUE IS 12
#
# 3. MEDIAN IS 12 4TH TERM .
#
# 4. 12 IS THE MOST REPRESENATIVE NUMBER

# %% [markdown]
# # Q2: Mean in Real Life.
# # A teacher records the marks of her students in a short quiz: [12, 15, 14, 16, 18, 20, 19].
#
# # What is the mean score, and what does it tell us about the class’s performance?
#
# ANSWER2. THE MEAN OF THIS VALUE IS (12+14+15+16+18+19+20/7) =16.28
#
# IT SHOW THAT AVERAGE MARKS OF ALL STUDENTS IS 16.28  AND THE PERFORMANCE IS OK NOT BAD.

# %% [markdown]
# # QUESTION3 . Mode in Real Life.
# # A store records the shoe sizes sold in one day: [7, 8, 9, 8, 8, 10, 7, 9].
# # **What is the mode, and why is this information useful for the store manager**
#
# ANSWER3.
# 1. MODE SHOWS THE MOST WHICH NUMBER REPEAT A LOT IN A VALUE.
#
# 2. THE MODE OF THIS NUMBER IS = 8.
#
# 3. IT A VERY INFORMATIVE FOR THE STORE WHICH SHOW THAT 8 NUMBER OF SHOE SIZE SELLS THE  MOST SO NEXT TIME STORE MANAGER  BRING  THE MORE 8 SIZE SHOE IN HIS STORE
#
# 4. OR IT ALSO SHOW THAT DEMAND OF 8 SIZE SHOE IS HIGH.

# %% [markdown]
# # Q4: Median in Real Life (Medium)
# # A car dealer notes the prices of used cars: [$8,000, $9,500, $10,200, $11,000, $50,000].
#
# # Why is the median a better measure than the mean in this case? Calculate the median
#
# ANSWER4.
# 1. MEDIAN SHOW THE MID VALUE OF NUMMBER .
#
# 2. MEAN IS BEST FOR ONLY LOW VALUE OF NUMBER BUT NOT FOR THE HIGH VALUES  ON THE OTHER HAND MEDIAN DOES NOT AFFECTED BY OUTLIER.
#
# 3. FOR THE EXTREME  VALUE MEDIAN IS THE BEST APPROACH  FOR THE TYPICAL CAR PRICE WITHOUT BEING DISTORTED BY THE UNUSALLY HIGH OUTLLIER.
#
# 4. MEDIAN OF THIS NUMBER IS = **10200**

# %% [markdown]
# # Q5: Dispersion Introduction (Medium)
# # A student times how long it takes to finish a puzzle each day: [25, 30, 27, 35, 40].
# # What does the range tell us about the variation in the student’s puzzle-solving time.
#
# ANSWER5.
# 1. VARIATION MEAN HOW MUCH DATA IS DIFFER OR SCATTER IS IN THIS VALUE
#
# 2. THE RANGE OF THIS DATA IS 15 (SMALL-LARGE NUMBER) 25-40=15
#
# 3. IT SHOW THAT STUDENT TAKING TIME HAVE A MODERATE VARIATION  NOT VERY HIGH OR LOW .

# %% [markdown]
# # Q6: Range in Action (Medium)
# # A farmer records the weekly weight of harvested apples (kg): [100, 105, 98, 110, 120].
# # Find the range. How can this help the farmer in planning his packaging?
#
# ANSWER6
#
# 1. THE RANGE OF THIS DATA IS = (98-120) 22.  WHICH  SHOW THAT HARVEST VARY SIGNIFICANTLY .
#
# 2. IT HELP THE FARMER TO PLAN FLEXIBLY
#
# 3. WHICH ALSO SAY  THAT FARMER HAVE MAXIMUM 120 KG APPLE PACKAGING AND LEAST 98 KG  SPACE WHICH DOES NOT LEAD ANY WASTAGE.

# %% [markdown]
# # Q7: Variance for Decision-Making (Medium)
# # Two delivery companies track delivery delays (in minutes).
# # Company A: variance = 6
# # Company B: variance = 15
# # Which company is more consistent, and why?
#
# ANSWER7
#
# 1. COMPANY A IS THE MOST CONSISTENT BECAUSE THERE IS VERY LESS VARIANCE IN DATA
# WHICH SHOW THAT IN DATA THERE IS NO HIGH VARIANCE WHICH MAKE  TO PREDICT VERY EASILY.
#
# 2. ON THE OTHER HAND COMPANY B HAVE A LOT OF VARIANCE IN THERE DATA WHICH MAKE TO PREDICT AND SHOW THAT COMPANY B IS VERY LESS CONSISTENT.

# %% [markdown]
# # Q8: Standard Deviation in Context (Hard)
# # A finance student compares the daily price fluctuations of two cryptocurrencies.
# # Coin A: standard deviation = $30
#
# # Coin B: standard deviation = $120
#
# # Which coin is riskier to invest in, and why
#
# ANSWER8
# 1. STANDARD DEVIATION SHOW THAT HOW MUCH DATA IS SCATTER OR DIIFER .
#
# 2. COIN B IS VERY RISKIER DUE TO HIGH STANDARD DEVIATION WHICH MAKE DIFFICULT TO PREDICT HIS NEXT VALUE.
#
# 3. MORE STANDARD DEVIATION MORE DATA DIFFER OR SCATTER .

# %% [markdown]
# # Q9: Combining Measures (Hard)
# # A family records their monthly electricity usage (in kWh): [400, 420, 390, 450, 410].
#
# # Find the mean and standard deviation. What do these values together tell you about the family energy use PATTERN ?
#
#  ANSWER9
#
#  1. MEAN OF THIS VALUES IS = (390+400+410+420+450/5) 414 KWH.
#
#  2. STANDARD DEVIATION IS = 20.59
#
#
#  ![WhatsApp Image 2025-12-11 at 14.12.56_28275c01.jpg](data:image/jpeg;base64,...)
#
#  3. MEAN IS 414KWH SHOW THEIR MONTHLY USAGE OF ELECTRICTY .
#
#  4. AND STAND DEVIATION IS NOT HIGH SO VARIANCE ARE NOT VERY MUCH NOT TOO MUCH FLUCTUATION IN USAGE.

# %% [markdown]
# # Q10: Practical Application (Hard)
# # A basketball player’s points in 8 games are recorded: [15, 18, 20, 22, 25, 17, 19, 21].
#
# # Find the mean, median, mode, range, and standard deviation. What insights can these measures provide about the player’s scoring performance?
#
# ANSWER10
#
# 1. MEAN = 15+17+18+19+20+21+22+25/8 = 19.625
#
#  THAT MEAN PLAYER GOAL 19 OR 20  IN A PER GAME
#
#
# 2. MEDIAN = 15+17+18+19+20+21+22+25
# 4TH AND 5TH TERM 19,20 = 19+20/2= 19.5
#
# CLOSE TO MEAN 19 THAT MEAN IT BALANCED AND SCORE 19 OR 20 PER GAME
#
# 3. MODE = NO REPEAT NUMBER
#
# 4. RANGE = 15-25 = 10
#
# ALL GOAL PER GAME ARE DIIFERENT SLIGHTLY VARIANCE
#
#
# 5. STANDARD DEVIATION IS = 2.91 FOR POPULATION
# FOR SAMPLE 3.11
#
# THAT MEAN PLAYER ARE VERY CONSISTENT AND PLAYED VERY WELL.
